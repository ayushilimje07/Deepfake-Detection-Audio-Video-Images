# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from resampy) (1.26.4)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.10/dist-packages (from resampy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.53->resampy) (0.43.0)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
import resampy

# %%
# Define paths and parameters
DATASET_PATH = "/content/drive/MyDrive/flac"
LABEL_FILE_PATH = "/content/ASVspoof2019.LA.cm.train.trn.txt"

# %%
# Function to extract MFCC features from audio files
def extract_features(file_name, n_mfcc=13):
    audio, sample_rate = librosa.load(file_name)
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    mfccs_scaled = np.mean(mfccs.T, axis=0)  # Average over time steps
    return mfccs_scaled

# Prepare dataset by extracting MFCC features and labeling data
def prepare_dataset(directory,true_labels):
    features = []
    labels = []

    for file_name,label in tqdm(true_labels.items()):

        file_path = os.path.join(DATASET_PATH, file_name + ".flac")
        # Extract MFCC features
        mfccs = extract_features(file_path)

        features.append(mfccs)
        labels.append(label)

    # Convert to DataFrame
    features_df = pd.DataFrame(features)
    labels_df = pd.DataFrame(labels, columns=['label'])

    return features_df, labels_df

# %%
labels = {}

with open(LABEL_FILE_PATH, 'r') as label_file:
    lines = label_file.readlines()

for line in lines:
    parts = line.strip().split()
    file_name = parts[1]
    label = 1 if parts[-1] == "bonafide" else 0
    labels[file_name] = label

# %%
# Prepare the dataset (features and labels)
X, y = prepare_dataset(DATASET_PATH,labels)

# Save the joined DataFrame to a CSV file
joined_df = X.join(y)
joined_df.to_csv('lstm_features.csv', index=True)
# Out:
# 100%|██████████| 25380/25380 [52:02<00:00,  8.13it/s]

# %%
# Load the saved DataFrame
joined_df = pd.read_csv('/content/drive/MyDrive/lstm_features.csv', index_col=0)

label_column_name = 'label'

# Separate features (X) and labels (y)
X = joined_df.drop(columns=[label_column_name])  # Drop the label column to get features
y = joined_df[label_column_name]  # Extract the labels

# Now X contains the features and y contains the labels
print(X.head())  # Preview features
print(y.head())  # Preview labels
# Out:
#            0          1          2          3          4         5          6  \
# 0 -340.46576  68.059070 -35.050150  24.371809 -28.190529 -8.960600  -8.901085
# 1 -355.99622  69.545460 -28.908500  18.978424 -14.055003 -2.905738  -9.397294
# 2 -373.61560  39.435337 -19.746440  25.922157 -15.953314  4.097039 -12.675958
# 3 -319.87698  80.508700 -31.289251  42.233246 -29.800552 -6.862468  -6.453714
# 4 -328.48077  81.522995 -20.260254  13.312571 -23.785854  3.490676  -9.622008
#
#           7          8         9         10         11        12
# 0 -7.615912  -7.617714 -3.879600 -14.866941  -9.684492 -1.344773
# 1 -8.371697  -4.280693 -6.113141 -12.172381  -6.693559  0.279947
# 2  2.323044  -6.137020 -4.498224 -11.993213  -3.207461  3.649426
# 3 -4.949106 -15.727765 -9.504248 -14.960540 -10.436328 -2.747709
# 4 -6.995473 -10.265596 -4.170619 -14.447294  -9.391664  2.160380
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
# First, shuffle the dataset
from sklearn.utils import shuffle

X, y = shuffle(X, y, random_state=42)

# Define the split ratios
train_ratio = 0.6
val_ratio = 02
test_ratio = 0..2

# Calculate the indices for splitting
train_index = int(train_ratio * len(X))
val_index = int((train_ratio + val_ratio) * len(X))

# Split the data
X_train, X_val, X_test = X[:train_index], X[train_index:val_index], X[val_index:]
y_train, y_val, y_test = y[:train_index], y[train_index:val_index], y[val_index:]

# %%
# Reshape input for LSTM: [samples, time steps, features]
X_train_reshaped = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
X_val_reshaped = np.array(X_val).reshape((X_val.shape[0], 1, X_val.shape[1]))
X_test_reshaped = np.array(X_test).reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build the LSTM model
model = Sequential()

# LSTM layer with 128 units
model.add(LSTM(128, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2]), return_sequences=False))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Dense layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))

# Output layer
model.add(Dense(1, activation='sigmoid'))  # Binary classification (AI vs Human)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 128)                 │          72,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 81,025 (316.50 KB)
#  Trainable params: 81,025 (316.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
X.shape
# Out:
# (25380, 13)

# %%
X_test.shape
# Out:
# (5076, 13)

# %%
# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=30, batch_size=32, validation_data=(X_val_reshaped, y_val))
# Out:
# Epoch 1/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8890 - loss: 0.3195 - val_accuracy: 0.8993 - val_loss: 0.2399
# Epoch 2/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8990 - loss: 0.2622 - val_accuracy: 0.9043 - val_loss: 0.2216
# Epoch 3/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9004 - loss: 0.2408 - val_accuracy: 0.9039 - val_loss: 0.2123
# Epoch 4/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8965 - loss: 0.2397 - val_accuracy: 0.9058 - val_loss: 0.2127
# Epoch 5/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9072 - loss: 0.2235 - val_accuracy: 0.9133 - val_loss: 0.2002
# Epoch 6/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9110 - loss: 0.2214 - val_accuracy: 0.9178 - val_loss: 0.1992
# Epoch 7/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9076 - loss: 0.2193 - val_accuracy: 0.9214 - val_loss: 0.1840
# Epoch 8/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9134 - loss: 0.2103 - val_accuracy: 0.9208 - val_loss: 0.1930
# Epoch 9/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9083 - loss: 0.2142 - val_accuracy: 0.9238 - val_loss: 0.1782
# Epoch 10/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9115 - loss: 0.2085 - val_accuracy: 0.9249 - val_loss: 0.1840
# Epoch 11/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9151 - loss: 0.2024 - val_accuracy: 0.9242 - val_loss: 0.1766
# Epoch 12/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9151 - loss: 0.1960 - val_accuracy: 0.9269 - val_loss: 0.1782
# Epoch 13/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9161 - loss: 0.2011 - val_accuracy: 0.9269 - val_loss: 0.1721
# Epoch 14/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9181 - loss: 0.1960 - val_accuracy: 0.9293 - val_loss: 0.1722
# Epoch 15/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9165 - loss: 0.1972 - val_accuracy: 0.9240 - val_loss: 0.1779
# Epoch 16/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9122 - loss: 0.1978 - val_accuracy: 0.9336 - val_loss: 0.1613
# Epoch 17/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9165 - loss: 0.1908 - val_accuracy: 0.9273 - val_loss: 0.1659
# Epoch 18/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9189 - loss: 0.1893 - val_accuracy: 0.9267 - val_loss: 0.1685
# Epoch 19/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9211 - loss: 0.1946 - val_accuracy: 0.9234 - val_loss: 0.1710
# Epoch 20/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9220 - loss: 0.1861 - val_accuracy: 0.9283 - val_loss: 0.1624
# Epoch 21/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9215 - loss: 0.1817 - val_accuracy: 0.9291 - val_loss: 0.1627
# Epoch 22/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9187 - loss: 0.1860 - val_accuracy: 0.9385 - val_loss: 0.1543
# Epoch 23/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9249 - loss: 0.1791 - val_accuracy: 0.9242 - val_loss: 0.1687
# Epoch 24/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9214 - loss: 0.1836 - val_accuracy: 0.9228 - val_loss: 0.1728
# Epoch 25/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9226 - loss: 0.1857 - val_accuracy: 0.9374 - val_loss: 0.1531
# Epoch 26/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9229 - loss: 0.1845 - val_accuracy: 0.9374 - val_loss: 0.1557
# Epoch 27/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9223 - loss: 0.1863 - val_accuracy: 0.9383 - val_loss: 0.1518
# Epoch 28/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9273 - loss: 0.1739 - val_accuracy: 0.9356 - val_loss: 0.1564
# Epoch 29/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9268 - loss: 0.1760 - val_accuracy: 0.9356 - val_loss: 0.1523
# Epoch 30/30
# 476/476 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9242 - loss: 0.1786 - val_accuracy: 0.9368 - val_loss: 0.1554

# %%
 # Save the model
model.save('/content/drive/MyDrive/lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_reshaped, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9362 - loss: 0.1488
# Test Accuracy: 93.16%

# %%
import pandas as pd

# Get predictions for the test set
y_pred = model.predict(X_test_reshaped)

# Convert probabilities to binary predictions (e.g., using a threshold of 0.5)
y_pred_binary = (y_pred > 0.45).astype(int)

# Create a DataFrame for comparison
comparison_df = pd.DataFrame({'Audio.No': X_test.index, 'Pred.Label': y_pred_binary.flatten(), 'Original.Label': y_test})

# Display the table
print(comparison_df)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#        Audio.No  Pred.Label  Original.Label
# 19692     19692           0               0
# 17888     17888           0               0
# 1806       1806           1               1
# 3871       3871           0               0
# 3791       3791           0               0
# ...         ...         ...             ...
# 21575     21575           0               0
# 5390       5390           0               0
# 860         860           1               1
# 15795     15795           0               0
# 23654     23654           0               0
#
# [5076 rows x 3 columns]

# %%
# Plot accuracy and loss history
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/lstm_model.h5')

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import pandas as pd

# Load features and labels from CSV
features_df = pd.read_csv('/content/drive/MyDrive/lstm_features.csv')
print("Shape of features:", features_df.shape)

# If labels are in a separate column or file
labels = features_df['label']  # Replace 'label' with the actual column name for labels
features_df = features_df.drop('label', axis=1)  # Remove label column from features

print("Shape of features after removing label column:", features_df.shape)
# Out:
# Shape of features: (25380, 15)
# Shape of features after removing label column: (25380, 14)

# %%
# Function to extract MFCC features from audio files
def extract_features(file_name, n_mfcc=13):
    audio, sample_rate = librosa.load(file_name)
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    mfccs_scaled = np.mean(mfccs.T, axis=0)  # Average over time steps
    return mfccs_scaled

# %%
import numpy as np
import librosa
def preprocess_audio(file_path):
    # Extract the MFCC features (which results in a shape of (13,))
    mfccs_scaled = extract_features(file_path)

    # Ensure the shape is (1, 1, 13) to match the model's expected input shape
    mfccs_scaled = np.expand_dims(mfccs_scaled, axis=0)  # Shape becomes (1, 13)
    mfccs_scaled = np.expand_dims(mfccs_scaled, axis=1)  # Shape becomes (1, 1, 13)

    return mfccs_scaled

# %%
# Example usage for prediction
new_audio_features = preprocess_audio('/content/drive/MyDrive/flac/LA_T_7149832.flac')
prediction = model.predict(new_audio_features)

# Output the prediction result
if prediction > 0.5:
    print("Bonafide")
else:
    print("Spoof")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Spoof

# %%
from IPython.display import Audio
Audio('/content/drive/MyDrive/flac/LA_T_7149832.flac')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import librosa

def plot_audio_waveform(audio, sample_rate):
    plt.figure(figsize=(10, 4))
    plt.plot(audio)
    plt.title("Audio Waveform")
    plt.xlabel("Samples")
    plt.ylabel("Amplitude")
    plt.grid()
    plt.show()

# Load the audio file
audio_file_path = '/content/drive/MyDrive/pradip.ogg'
new_audio_features = preprocess_audio(audio_file_path)
print(new_audio_features)
audio, sample_rate = librosa.load(audio_file_path, sr=None)  # sr=None to use the original sample rate

# Example usage
plot_audio_waveform(audio, sample_rate)
# Out:
# [[[-2.0987180e+02  1.4631435e+02 -4.7849812e+01  5.2626701e+01
#    -1.3562957e+01 -2.1163536e-02  2.1079716e-01 -1.9746025e+01
#    -1.5314134e+01  8.8781726e-01 -1.5458457e+01 -9.5459642e+00
#     8.2109327e+00]]]

# %%
import matplotlib.pyplot as plt
import librosa

def plot_audio_waveform(audio, sample_rate):
    plt.figure(figsize=(10, 4))
    plt.plot(audio)
    plt.title("Audio Waveform")
    plt.xlabel("Samples")
    plt.ylabel("Amplitude")
    plt.grid()
    plt.show()

# Load the audio file
audio_file_path = '/content/drive/MyDrive/flac/LA_T_7149832.flac'
new_audio_features = preprocess_audio(audio_file_path)
print(new_audio_features)
audio, sample_rate = librosa.load(audio_file_path, sr=None)  # sr=None to use the original sample rate

# Example usage
plot_audio_waveform(audio, sample_rate)
# Out:
# [[[-395.29904      92.53311     -18.682234     22.719236      1.9708037
#      -4.7031455   -14.531585     -0.46180236  -23.438263     -9.426815
#      -9.0939865   -17.582636      2.7938383 ]]]
